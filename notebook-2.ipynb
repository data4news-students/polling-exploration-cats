# %% [markdown]
# # Python and R

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# show all columns on pandas dataframes
pd.set_option('display.max_columns', None)

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# # My commonly used R imports
#
# require('tidyverse')
# Out:
# R[write to console]: Loading required package: tidyverse
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# # Read the data

# %% [markdown]
# The cell below loads the data in python:

# %%
df = pd.read_csv('raw-polls.csv')
df.sample(5)
# Out:
#       poll_id  question_id  race_id  year                race location  \
# 8544    48261        75568      611  2016      2016_Pres-G_FL       FL
# 3812     2204         2779     7414  2008      2008_Pres-D_PA       PA
# 2796    25008        89079     1345  2006       2006_Gov-G_MN       MN
# 2810    55509        30243     1591  2006       2006_Sen-G_MI       MI
# 2861    64241       118210     3869  2006  2006_House-G_NY-20    NY-20
#
#      type_simple type_detail                        pollster  \
# 8544      Pres-G      Pres-G                Gravis Marketing
# 3812      Pres-P      Pres-D           Quinnipiac University
# 2796       Gov-G       Gov-G  Zogby Interactive/JZ Analytics
# 2810       Sen-G       Sen-G  Zogby Interactive/JZ Analytics
# 2861     House-G     House-G                   RT Strategies
#
#       pollster_rating_id methodology partisan  polldate  samplesize  \
# 8544                 124         IVR        R  10/31/16      1195.0
# 3812                 267  Live Phone      NaN   4/19/08      1027.0
# 2796                 395      Online      NaN  10/25/06       715.0
# 2810                 395      Online      NaN  10/25/06      1081.0
# 2861                 275  Live Phone      NaN  10/25/06      1040.0
#
#                   cand1_name  cand1_id cand1_party  cand1_pct  \
# 8544  Hillary Rodham Clinton      9207         DEM       50.0
# 3812  Hillary Rodham Clinton        45         DEM       51.0
# 2796              Mike Hatch     12715         DEM       46.1
# 2810         Debbie Stabenow      2915         DEM       49.3
# 2861   Kirsten E. Gillibrand     13928         DEM       53.0
#
#            cand2_name  cand2_id cand2_party  cand2_pct  cand3_pct  \
# 8544     Donald Trump      9849         REP       47.5        2.0
# 3812     Barack Obama        41         DEM       44.0        NaN
# 2796     Tim Pawlenty     12717         REP       44.7        6.3
# 2810    Mike Bouchard      2916         REP       41.9        NaN
# 2861  John E. Sweeney     13929         REP       42.0        NaN
#
#       margin_poll electiondate  cand1_actual  cand2_actual  margin_actual  \
# 8544          2.5      11/8/16         47.82         49.02          -1.20
# 3812          7.0      4/22/08         54.57         45.43           9.14
# 2796          1.4      11/7/06         45.73         46.69          -0.96
# 2810          7.4      11/7/06         56.91         41.26          15.65
# 2861         11.0      11/7/06         53.10         46.90           6.20
#
#       bias  rightcall                                            comment
# 8544  3.70        0.0  for unspecified Republican sponsor; average of...
# 3812   NaN        1.0                                                NaN
# 2796  2.36        0.0                            for Wall Street Journal
# 2810 -8.25        1.0                            for Wall Street Journal
# 2861  4.80        1.0                                                NaN

# %% [markdown]
# The cell below loads the same data in R:

# %%
# %%R
#
# df <- read_csv('raw-polls.csv')
#
# df
# Out:
# Rows: 10776 Columns: 31
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (14): race, location, type_simple, type_detail, pollster, methodology, p...
# dbl (17): poll_id, question_id, race_id, year, pollster_rating_id, samplesiz...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# # A tibble: 10,776 × 31
#    poll_id questio…¹ race_id  year race  locat…² type_…³ type_…⁴ polls…⁵ polls…⁶
#      <dbl>     <dbl>   <dbl> <dbl> <chr> <chr>   <chr>   <chr>   <chr>     <dbl>
#  1   26013     87909    1455  1998 1998… NY      Gov-G   Gov-G   Blum &…      32
#  2   26255     87926    1456  1998 1998… OH      Gov-G   Gov-G   Univer…     346
#  3   26026     31266    1736  1998 1998… NV      Sen-G   Sen-G   FM3 Re…      91
#  4   26013     31253    1738  1998 1998… NY      Sen-G   Sen-G   Blum &…      32
#  5   63632    117103    1738  1998 1998… NY      Sen-G   Sen-G   Garin-…     113
#  6   26255     31495    1741  1998 1998… OH      Sen-G   Sen-G   Univer…     346
#  7   64053    117875    1966  1998 1998… ID-1    House-G House-G Garin-…     113
#  8   64053    117876    1967  1998 1998… ID-2    House-G House-G Garin-…     113
#  9   28268     33546    8661  1998 1998… US      House-G House-G CBS Ne…      36
# 10   28267     33545    8661  1998 1998… US      House-G House-G Zogby …     395
# # … with 10,766 more rows, 21 more variables: methodology <chr>,
# #   partisan <chr>, polldate <chr>, samplesize <dbl>, cand1_name <chr>,
# #   cand1_id <dbl>, cand1_party <chr>, cand1_pct <dbl>, cand2_name <chr>,
# #   cand2_id <dbl>, cand2_party <chr>, cand2_pct <dbl>, cand3_pct <dbl>,
# #   margin_poll <dbl>, electiondate <chr>, cand1_actual <dbl>,
# #   cand2_actual <dbl>, margin_actual <dbl>, bias <dbl>, rightcall <dbl>,
# #   comment <chr>, and abbreviated variable names ¹​question_id, ²​location, …
# # ℹ Use `print(n = ...)` to see more rows, and `colnames()` to see all variable names

# %% [markdown]
# ### R + Tidyverse refresher

# %% [markdown]
# Here are a few functions that might help you in R and tidyverse.

# %% [markdown]
# ### Subsetting data with `filter`
#
# <img src="images/filter.png" width="300">
#
# Let's filter the data down to presidential polls only.
#
# In Python you might do the following
#
# ```python
# new_df = df[df['type_simple'] == 'Pres-G']
# ```
#
# In R (with the help of tidyverse) that looks like this:

# %%
# %%R
#
# new_df <- df %>% filter(type_simple=='Pres-G')

# %% [markdown]
# ### Adding columns with `mutate`
#
# <img src="images/mutate.png" width="300">
#
# Let's add a true/false column for whether a poll is a nationwide poll or not
#
# In Python you might do the following
#
# ```python
# new_df = df
# new_df["nationwide"] = new_df['location'] == 'US'
# ```
#
# In R (with the help of tidyverse) that looks like this:

# %%
# %%R
#
# new_df <- df %>% mutate(national = location=="US")

# %% [markdown]
# ### Combining transormations using the pipe (`%>%`)

# %%
# %%R
#
# new_df <- df %>%
#     filter(type_simple=='Pres-G') %>% # filter to pres general election polls only
#     mutate(national = location=="US") %>% # make a new True/False nationwide column
#     filter(national==TRUE) # make a new True/False nationwide column

# %% [markdown]
# # ggplot refresher
#
# Here are some very basic charts to get you started at looking at how far off these polls have been relative to the actual results of elections (`bias` variable).
#
# You will probably need to modify them significantly to get anything meaningful out of your exploratory dataviz.
#
# Think about which variables you might need to facet on the histogram (or what you might want to set the y axis to on the dotplot).

# %%
# %%R -h 200
#
# # Filter data to polls in presidential general elections only
# df_pres_general <- df %>% filter(type_simple=='Pres-G')
#
# # plot the `bias` variable, which shows how far away from the
# # actual result each poll's result was...
# ggplot(df_pres_general) +
#     aes(x=bias, y=1, color=bias>0, alpha=.05) +
#     geom_point() +
#     geom_vline(aes(xintercept=0), color='red')  +
#     labs(
#         title='Inaccuracy of polls in presidential elections',
#         subtitle="positive numbers = polls overestimated DEM support\nnegative numbers= polls overestimated GOP support"
#     ) +
#     theme(legend.position="none")

# %% [markdown]
# #### 👉 Try it
#
# Make some basic changes to this chart
# 1. set the y axis to the year _(hint: you might need to learn about `factor` in R)_
# 2. filter the data down to national level presidential general election polls only and plot it on the same dotplot

# %%
# %%R -h 200
#
# # Paste code below:
#
# ggplot(new_df) +
#     aes(x=bias, y=year, color=bias>0, alpha=.05) +
#     geom_point() +
#     geom_vline(aes(xintercept=0), color='red')  +
#     labs(
#         title='Inaccuracy of polls in presidential elections',
#         subtitle="positive numbers = polls overestimated DEM support\nnegative numbers= polls overestimated GOP support"
#     ) +
#     theme(legend.position="none")

# %%
# %%R
#
# df_pres_general <- df %>%
#     filter(type_simple=='Pres-G') # Filter data to polls in presidential general elections only
#
# # a basic histogram
# ggplot(df_pres_general) +
#     aes(x=bias) +
#     geom_histogram(bins=80) +
#     geom_vline(aes(xintercept=0), color='red') +
#     labs(
#         title='Inaccuracy of polls in presidential elections',
#         subtitle="positive numbers = polls overestimated DEM support\nnegative numbers= polls overestimated GOP support",
#         )

# %%
df.query("type_simple == 'Pres-G' and location=='US'")
# Out:
#        poll_id  question_id  race_id  year            race location  \
# 470       6478         7947       40  2000  2000_Pres-G_US       US
# 481       6459       123272       40  2000  2000_Pres-G_US       US
# 482      63601       117065       40  2000  2000_Pres-G_US       US
# 496       6449         7918       40  2000  2000_Pres-G_US       US
# 497      37111       116971       40  2000  2000_Pres-G_US       US
# ...        ...          ...      ...   ...             ...      ...
# 10703    72652       136338     6210  2020  2020_Pres-G_US       US
# 10704    72809       136668     6210  2020  2020_Pres-G_US       US
# 10705    72790       136572     6210  2020  2020_Pres-G_US       US
# 10706    72714       136475     6210  2020  2020_Pres-G_US       US
# 10737    73830       138491     6210  2020  2020_Pres-G_US       US
#
#       type_simple type_detail                                  pollster  \
# 470        Pres-G      Pres-G            Zogby Interactive/JZ Analytics
# 481        Pres-G      Pres-G          NBC News/The Wall Street Journal
# 482        Pres-G      Pres-G  Rasmussen Reports/Pulse Opinion Research
# 496        Pres-G      Pres-G              ABC News/The Washington Post
# 497        Pres-G      Pres-G           Fox News/Opinion Dynamics Corp.
# ...           ...         ...                                       ...
# 10703      Pres-G      Pres-G                              Research Co.
# 10704      Pres-G      Pres-G                              SurveyMonkey
# 10705      Pres-G      Pres-G                                  Swayable
# 10706      Pres-G      Pres-G                                    YouGov
# 10737      Pres-G      Pres-G                    Lake Research Partners
#
#        pollster_rating_id methodology partisan  polldate  samplesize  \
# 470                   395  Live Phone      NaN  10/17/00      1200.0
# 481                   221  Live Phone      NaN  10/18/00       600.0
# 482                   277         IVR      NaN  10/18/00      3750.0
# 496                     3  Live Phone      NaN  10/19/00      1020.0
# 497                   104  Live Phone      NaN  10/19/00       900.0
# ...                   ...         ...      ...       ...         ...
# 10703                 449      Online      NaN   11/1/20      1025.0
# 10704                 324      Online      NaN   11/1/20     28240.0
# 10705                 543      Online      NaN   11/1/20      5174.0
# 10706                 391      Online      NaN   11/1/20      1363.0
# 10737                 165  Live Phone        D   11/2/20      2400.0
#
#                 cand1_name  cand1_id cand1_party  cand1_pct      cand2_name  \
# 470                Al Gore       222         DEM       43.0  George W. Bush
# 481                Al Gore       222         DEM       43.0  George W. Bush
# 482                Al Gore       222         DEM       46.0  George W. Bush
# 496                Al Gore       222         DEM       45.0  George W. Bush
# 497                Al Gore       222         DEM       42.0  George W. Bush
# ...                    ...       ...         ...        ...             ...
# 10703  Joseph R. Biden Jr.     13256         DEM       50.0    Donald Trump
# 10704  Joseph R. Biden Jr.     13256         DEM       52.0    Donald Trump
# 10705  Joseph R. Biden Jr.     13256         DEM       51.8    Donald Trump
# 10706  Joseph R. Biden Jr.     13256         DEM       53.0    Donald Trump
# 10737  Joseph R. Biden Jr.     13256         DEM       51.0    Donald Trump
#
#        cand2_id cand2_party  cand2_pct  cand3_pct  margin_poll electiondate  \
# 470         241         REP       44.0        5.0         -1.0      11/7/00
# 481         241         REP       45.0        3.0         -2.0      11/7/00
# 482         241         REP       41.0        NaN          5.0      11/7/00
# 496         241         REP       47.0        3.0         -2.0      11/7/00
# 497         241         REP       45.0        4.0         -3.0      11/7/00
# ...         ...         ...        ...        ...          ...          ...
# 10703     13254         REP       42.0        1.0          8.0      11/3/20
# 10704     13254         REP       46.0        NaN          6.0      11/3/20
# 10705     13254         REP       46.1        1.7          5.7      11/3/20
# 10706     13254         REP       43.0        NaN         10.0      11/3/20
# 10737     13254         REP       48.0        NaN          3.0      11/3/20
#
#        cand1_actual  cand2_actual  margin_actual  bias  rightcall  \
# 470           48.31         47.79           0.51 -1.51        0.0
# 481           48.31         47.79           0.51 -2.51        0.0
# 482           48.31         47.79           0.51  4.49        1.0
# 496           48.31         47.79           0.51 -2.51        0.0
# 497           48.31         47.79           0.51 -3.51        0.0
# ...             ...           ...            ...   ...        ...
# 10703         51.31         46.86           4.45  3.55        1.0
# 10704         51.31         46.86           4.45  1.55        1.0
# 10705         51.31         46.86           4.45  1.25        1.0
# 10706         51.31         46.86           4.45  5.55        1.0
# 10737         51.31         46.86           4.45 -1.45        1.0
#
#                                                  comment
# 470                                  for Reuters | MSNBC
# 481    sample size unavailable; estimated at 600 as a...
# 482                                                  NaN
# 496                                                  NaN
# 497                                                  NaN
# ...                                                  ...
# 10703                                                NaN
# 10704                                          for Axios
# 10705                                                NaN
# 10706                                      for Economist
# 10737                 for unspecified Democratic sponsor
#
# [488 rows x 31 columns]

# %% [markdown]
# ### Summary Statistics Refresher

# %% [markdown]
# #### Basic summary stats of a column in Python and in R

# %%
# Python
df.bias.describe()
# Out:
# count    8824.000000
# mean        0.626282
# std         6.329518
# min       -40.240000
# 25%        -3.332500
# 50%         0.680000
# 75%         4.620000
# max        42.940000
# Name: bias, dtype: float64

# %%
# %%R
#
# df$bias %>% summary()
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.     NA's
# -40.2400  -3.3325   0.6800   0.6263   4.6200  42.9400     1952

# %% [markdown]
# #### Basic pivot table in Python and R

# %%
pres_df = df.query("type_simple=='Pres-G' & location=='US'")

pres_df.pivot_table(
    index='year', 
    values='bias', 
    aggfunc=['mean','median','std', 'count'])
# Out:
#           mean median       std count
#           bias   bias      bias  bias
# year
# 2000 -2.962000  -3.01  3.444909    75
# 2004  0.916923   1.46  2.514332    65
# 2008  0.011319  -0.27  2.810690    91
# 2012 -3.432706  -2.85  2.305543    85
# 2016  1.552308   1.65  3.361668    78
# 2020  3.829681   4.05  2.944325    94

# %%
# %%R
#
# pres_df <- df %>%
#     filter(type_simple=='Pres-G') %>%
#     filter(location=='US')
#
#
# pres_df %>%
#   group_by(year) %>%
#   summarise(mean = mean(bias),
#            median = median(bias),
#            stdev = sd(bias),
#            num_polls=n())
# Out:
# # A tibble: 6 × 5
#    year    mean median stdev num_polls
#   <dbl>   <dbl>  <dbl> <dbl>     <int>
# 1  2000 -2.96    -3.01  3.44        75
# 2  2004  0.917    1.46  2.51        65
# 3  2008  0.0113  -0.27  2.81        91
# 4  2012 -3.43    -2.85  2.31        85
# 5  2016  1.55     1.65  3.36        78
# 6  2020  3.83     4.05  2.94        94
